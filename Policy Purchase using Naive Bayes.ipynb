# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB,CategoricalNB,ComplementNB

# %%
df = pd.read_csv("/content/social_network_ads.csv")

# %%
df

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()
df['Gender']=encoder.fit_transform(df['Gender'])

# %%
df['Gender']

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.loc[0:,['Age','EstimatedSalary']]

# %%
df.iloc[:,4]

# %%
x = df.loc[:,['Age','Gender','EstimatedSalary']]
y = df.iloc[:,4]

# %%
print(x.shape)
y=df['Purchased'].values.reshape(-1,1)
print(y.shape)
# Out:
# (400, 3)
# (400, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaler.fit_transform(X_train)
scaler.fit_transform(X_test)

# %%
gn = GaussianNB()

# %%
gn.fit(X_train, y_train)

# %%
pred=gn.predict(x)

# %%
print(pred)
print(y_test)

# %%
plt.plot(x,pred)
plt.ylabel('Purchased')
plt.xlabel('Estimated Salary')
# Out:
# Text(0.5, 0, 'Estimated Salary')

# %%
ml = MultinomialNB()
ml.fit(X_train,y_train)

# %%
pred1=ml.predict(x)
print(pred1)
print(y_test)

# %%
plt.plot(x,pred1)
plt.ylabel('Purchased')
plt.xlabel('Estimated Salary')
# Out:
# Text(0.5, 0, 'Estimated Salary')

# %%
bn = BernoulliNB()
bn.fit(X_train,y_train)
pred2 = bn.predict(x)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plt.plot(x,pred2)
plt.ylabel('Purchased')
plt.xlabel('Estimated Salary')
# Out:
# Text(0.5, 0, 'Estimated Salary')

# %%
cg = CategoricalNB()
cg.fit(X_train, y_train)
pred3 = cg.predict(x)
plt.ylabel('Purchased')
plt.xlabel('Estimated Salary')
plt.plot(x,pred3)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [<matplotlib.lines.Line2D at 0x7f73c91e6dc0>,
#  <matplotlib.lines.Line2D at 0x7f73c91e6f10>,
#  <matplotlib.lines.Line2D at 0x7f73c91e6fd0>]

# %%
cm = ComplementNB()
cm.fit(X_train,y_train)
pred4 = cm.predict(x)
plt.ylabel('Purchased')
plt.xlabel('Estimated Salary')
plt.plot(x,pred4)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [<matplotlib.lines.Line2D at 0x7f73c91c2d30>,
#  <matplotlib.lines.Line2D at 0x7f73c91c2e80>,
#  <matplotlib.lines.Line2D at 0x7f73c91c2f40>]

# %%
df.to_csv("PolicyPurchase")
