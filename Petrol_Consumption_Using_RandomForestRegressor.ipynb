# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshanand336/Data-Science-Projects/blob/main/Petrol_Consumption_Using_RandomForestRegressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/petrol_consumption.csv')

# %%
df.describe()
df.shape
df.head(40)
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
x=df.drop('Petrol_Consumption',axis=1)
y=df.Petrol_Consumption

# %%
x
y

# %%
X_train, X_test, y_test, y_train = train_test_split(x,y, test_size=0.3, random_state= 25)

# %%
X_test

# %%
rfr = RandomForestRegressor(n_estimators = 15, random_state = 0)
rfr.fit(X_test,y_train)
pred = rfr.predict(X_test)

# %%
pred
# Out:
# array([596.33333333, 578.13333333, 605.8       , 649.73333333,
#        608.93333333, 491.4       , 614.2       , 636.2       ,
#        652.53333333, 641.73333333, 614.26666667, 569.13333333,
#        654.53333333, 490.93333333, 424.8       ])

# %%
print("Mean Absolute Error : ", metrics.mean_absolute_error(y_train,pred))
print("Mean Squared Error: ", metrics.mean_squared_error(y_train,pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_train, pred)))
# Out:
# Mean Absolute Error :  22.857777777777777
# Mean Squared Error:  1028.1549629629633
# Root Mean Squared Error: 32.06485557371128

# %%
metrics.r2_score(y_train, pred)
# Out:
# 0.864959998069758

# %%
df=pd.DataFrame({'Actual':y_train, 'Predicted':pred})
df
# Out:
#     Actual   Predicted
# 43     591  596.333333
# 14     566  578.133333
# 40     587  605.800000
# 33     628  649.733333
# 46     610  608.933333
# 7      467  491.400000
# 32     577  614.200000
# 19     640  636.200000
# 38     648  652.533333
# 35     644  641.733333
# 30     571  614.266667
# 2      561  569.133333
# 17     714  654.533333
# 11     471  490.933333
# 6      344  424.800000
